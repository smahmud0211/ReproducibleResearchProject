# %% [markdown]
# # CO2 Data Exploration
# This notebook checks the cleaned CO2 dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/co2_clean.csv')
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.sort_values('co2_pc', ascending=False)[['country','year','co2_pc']].head(10)
